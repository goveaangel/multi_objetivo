# %%
#!pip install pymoo
# Out:
# Requirement already satisfied: pymoo in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (0.6.1.5)
# Requirement already satisfied: numpy>=1.19.3 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (2.3.4)
# Requirement already satisfied: scipy>=1.1 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (1.16.2)
# Requirement already satisfied: matplotlib>=3 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (3.10.7)
# Requirement already satisfied: autograd>=1.4 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (1.8.0)
# Requirement already satisfied: cma>=3.2.2 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (4.4.0)
# Requirement already satisfied: alive-progress in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (3.3.0)
# Requirement already satisfied: dill in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (0.4.0)
# Requirement already satisfied: Deprecated in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from pymoo) (1.2.18)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from matplotlib>=3->pymoo) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo) (1.17.0)
# Requirement already satisfied: about-time==4.2.1 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from alive-progress->pymoo) (4.2.1)
# Requirement already satisfied: graphemeu==0.7.2 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from alive-progress->pymoo) (0.7.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/angelgovea/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/5to Semestre/Diseño de algoritmos matemáticos bioinspirados/multi_objetivo/multiObj/lib/python3.13/site-packages (from Deprecated->pymoo) (1.17.3)

# %%
# NSGA-II con ZDT1 y DTLZ2
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.problems import get_problem
from pymoo.optimize import minimize
from pymoo.indicators.igd import IGD
from pymoo.indicators.hv import HV
import numpy as np
import matplotlib.pyplot as plt

# %%
# CONFIGURACIÓN GENERAL
pop_size = 100
n_evals = 10000
n_gen = n_evals // pop_size
seeds = [42, 123, 456]

# %%
# FUNCIÓN AUXILIAR: Ejecuta NSGA-II y calcula métricas
def ejecutar_nsga2(nombre_problema):
    print(f"\n=== Ejecutando {nombre_problema.upper()} ===")
    problem = get_problem(nombre_problema)
    algorithm = NSGA2(pop_size=pop_size)
    results = []

    # --- Ejecutar múltiples veces con distintas semillas ---
    for seed in seeds:
        res = minimize(problem,
                       algorithm,
                       termination=('n_gen', n_gen),
                       seed=seed,
                       verbose=False)
        results.append(res)

    # --- Frente verdadero ---
    true_pf = problem.pareto_front()

    # --- Calcular métricas ---
    igd_values, hv_values = [], []
    ref_point = np.max(true_pf, axis=0) * 1.1

    for i, res in enumerate(results):
        F = res.F
        igd_val = IGD(true_pf)(F)
        hv_val = HV(ref_point=ref_point)(F)
        igd_values.append(igd_val)
        hv_values.append(hv_val)
        print(f"  Semilla {seeds[i]} -> IGD: {igd_val:.4f} | HV: {hv_val:.4f}")

    print(f"  IGD promedio: {np.mean(igd_values):.4f}")
    print(f"  HV promedio:  {np.mean(hv_values):.4f}")

    # --- Guardar resultados ---
    rep = results[0]
    np.savez(f"resultados_{nombre_problema}.npz",
             F=rep.F, X=rep.X,
             IGD=igd_values, HV=hv_values, seeds=seeds)

    # --- Visualización ---
    if rep.F.shape[1] == 2:
        plt.scatter(rep.F[:, 0], rep.F[:, 1], s=20, color='#2ca02c', label="Frente obtenido")
        plt.scatter(true_pf[:, 0], true_pf[:, 1], s=10, color='#1f77b4', label="Frente verdadero", alpha=0.6)
        plt.title(f"Frente de Pareto — {nombre_problema.upper()}")
        plt.xlabel("f1")
        plt.ylabel("f2")
        plt.legend()
        plt.grid(alpha=0.3)
        plt.show()

    elif rep.F.shape[1] == 3:
        from mpl_toolkits.mplot3d import Axes3D
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(rep.F[:, 0], rep.F[:, 1], rep.F[:, 2], s=15, color='#2ca02c', label="Frente obtenido")
        ax.set_title(f"Frente de Pareto — {nombre_problema.upper()}")
        ax.set_xlabel("f1")
        ax.set_ylabel("f2")
        ax.set_zlabel("f3")
        plt.legend()
        plt.show()

    return igd_values, hv_values

# %%
# EJECUCIÓN
igd_zdt1, hv_zdt1 = ejecutar_nsga2("zdt1")
igd_dtlz2, hv_dtlz2 = ejecutar_nsga2("dtlz2")

# RESUMEN FINAL con promedio y std
print("\n=== RESUMEN FINAL CON STD ===")
for i, seed in enumerate(seeds):
    print(f"Semilla {seed} -> ZDT1: IGD={igd_zdt1[i]:.4f}, HV={hv_zdt1[i]:.4f} | "
          f"DTLZ2: IGD={igd_dtlz2[i]:.4f}, HV={hv_dtlz2[i]:.4f}")

# Promedios
print(f"\nPromedios ZDT1 -> IGD={np.mean(igd_zdt1):.4f} ± {np.std(igd_zdt1):.4f}, "
      f"HV={np.mean(hv_zdt1):.4f} ± {np.std(hv_zdt1):.4f}")
print(f"Promedios DTLZ2 -> IGD={np.mean(igd_dtlz2):.4f} ± {np.std(igd_dtlz2):.4f}, "
      f"HV={np.mean(hv_dtlz2):.4f} ± {np.std(hv_dtlz2):.4f}")
# Out:
# === Ejecutando ZDT1 ===
#   Semilla 42 -> IGD: 0.0218 | HV: 0.8381
#   Semilla 123 -> IGD: 0.0114 | HV: 0.8556
#   Semilla 456 -> IGD: 0.0193 | HV: 0.8427
#   IGD promedio: 0.0175
#   HV promedio:  0.8455
# === Ejecutando DTLZ2 ===
#   Semilla 42 -> IGD: 0.0689 | HV: 0.6947
#   Semilla 123 -> IGD: 0.0679 | HV: 0.7022
#   Semilla 456 -> IGD: 0.0730 | HV: 0.7045
#   IGD promedio: 0.0699
#   HV promedio:  0.7005
# === RESUMEN FINAL CON STD ===
# Semilla 42 -> ZDT1: IGD=0.0218, HV=0.8381 | DTLZ2: IGD=0.0689, HV=0.6947
# Semilla 123 -> ZDT1: IGD=0.0114, HV=0.8556 | DTLZ2: IGD=0.0679, HV=0.7022
# Semilla 456 -> ZDT1: IGD=0.0193, HV=0.8427 | DTLZ2: IGD=0.0730, HV=0.7045
#
# Promedios ZDT1 -> IGD=0.0175 ± 0.0045, HV=0.8455 ± 0.0074
# Promedios DTLZ2 -> IGD=0.0699 ± 0.0022, HV=0.7005 ± 0.0042
